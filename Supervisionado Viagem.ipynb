# %% [markdown]
# # **Aprendizado de Máquina Supervisionado**
#
# ---

# %% [markdown]
# # *Este projeto tem por objetivo desenvolver algoritmos de Machine Learning para prever a tendência de gastos de viagens a serviço são solicitados pelo órgãos do Departamento de Polícia Federal ou pelo Instituto Nacional do Seguro Social.*
#
# fonte: Portal da Transparência, site: https://www.portaltransparencia.gov.br/download-de-dados/viagens

# %% [markdown]
# # **PRÉ-PROCESSAMENTO**

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
viagem = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Trabalho2Bim/Supervisionado/Viagem/Viagem_limpo.csv',
                    sep=',', encoding='utf-8')

# %%
viagem.head()
# Out:
#    id_viagem                orgao_solicitante  \
# 0   12463176  Departamento de Polícia Federal
# 1   12463177  Departamento de Polícia Federal
# 2   12463178  Departamento de Polícia Federal
# 3   12463180  Departamento de Polícia Federal
# 4   12463181  Departamento de Polícia Federal
#
#                                 nome                              cargo  \
# 0  Informações protegidas por sigilo  Informações protegidas por sigilo
# 1  Informações protegidas por sigilo  Informações protegidas por sigilo
# 2  Informações protegidas por sigilo  Informações protegidas por sigilo
# 3  Informações protegidas por sigilo  Informações protegidas por sigilo
# 4  Informações protegidas por sigilo  Informações protegidas por sigilo
#
#      funcao    data_ini    data_fim  \
# 0  Sigilosa  04/01/2016  26/02/2016
# 1  Sigilosa  01/01/2016  31/01/2016
# 2  Sigilosa  01/01/2016  11/01/2016
# 3  Sigilosa  01/01/2016  11/01/2016
# 4  Sigilosa  11/01/2016  15/01/2016
#
#                                               motivo  valor_diarias  \
# 0  Informação protegida por sigilo nos termos da ...        8791.50
# 1  Informação protegida por sigilo nos termos da ...        6139.20
# 2  Informação protegida por sigilo nos termos da ...        1822.08
# 3  Informação protegida por sigilo nos termos da ...        1715.40
# 4  Informação protegida por sigilo nos termos da ...         919.45
#
#    valor_passagens  valor_devolucao  valor_outros_ gastos  valor_total
# 0              0.0              0.0                   0.0      8791.50
# 1              0.0              0.0                   0.0      6139.20
# 2              0.0              0.0                   0.0      1822.08
# 3              0.0              0.0                   0.0      1715.40
# 4              0.0              0.0                   0.0       919.45

# %%
viagem.describe()
# Out:
#           id_viagem  valor_diarias  valor_passagens  valor_devolucao  \
# count  8.543700e+05  854370.000000    854370.000000     8.543700e+05
# mean   1.841664e+07    1158.550487       431.260704     1.914205e+01
# std    1.042799e+08    4621.228568      1085.081525     1.841412e+03
# min    1.246318e+07       0.000000         0.000000     0.000000e+00
# 25%    1.272020e+07      85.380000         0.000000     0.000000e+00
# 50%    1.297258e+07     380.040000         0.000000     0.000000e+00
# 75%    1.322692e+07     772.220000       593.720000     0.000000e+00
# max    2.017001e+09   93715.600000    134098.000000     1.691843e+06
#
#        valor_outros_ gastos   valor_total
# count         854370.000000  8.543700e+05
# mean               5.164900  1.614118e+03
# std               39.865532  5.235432e+03
# min                0.000000  0.000000e+00
# 25%                0.000000  1.849100e+02
# 50%                0.000000  5.367900e+02
# 75%                0.000000  1.497690e+03
# max             6062.420000  1.710951e+06

# %% [markdown]
# ## Gerando filtros para criar amostra

# %%
viagem['orgao_solicitante'].value_counts()
# Out:
# Departamento de Polícia Federal                      66990
# Instituto Nacional do Seguro Social                  65809
# Ministério da Saúde - Unidades com vínculo direto    42270
# Comando da Aeronáutica                               39715
# Departamento de Polícia Rodoviária Federal           36774
#                                                      ...
# Fundação Escola Nacional de Administração Pública      112
# Empresa de Planejamento e Logística S.A.                89
# Fundação Biblioteca Nacional                            68
# Instituto Federal de Brasília                           55
# Instituto Nacional de Tecnologia da Informação          38
# Name: orgao_solicitante, Length: 190, dtype: int64

# %%
viagem['nome'].value_counts()
# Out:
# Informações protegidas por sigilo    109744
# SAUL ALBERTO SILVEIRA TEIXEIRA          221
# LEANDRO JONES BAZZANELLA                213
# JOAO BATISTA DA SILVA                   198
# NARCISO CEZAR RIBEIRO PROTETTI          197
#                                       ...
# KLEBERT DE LIMA SILVA                     1
# JOSE RAIMUNDO SANTOS MADEIRA              1
# ANA PAULA MUSSI SZABO CHEROBIM            1
# JOSE FRANCIEL VIEIRA ERICEIRA             1
# PAULO JUNIOR RODRIGUES PEREIRA            1
# Name: nome, Length: 216635, dtype: int64

# %%
viagem['cargo'].value_counts()
# Out:
# Desconhecido                             184362
# Informações protegidas por sigilo        109744
# PROFESSOR DO MAGISTERIO SUPERIOR          77027
# PROFESSOR ENS BASICO TECN TECNOLOGICO     54558
# TECNICO DO SEGURO SOCIAL                  20672
#                                           ...
# ANALISTA IV                                   1
# AGENTE ANALISTA GRAF FIS SUP                  1
# AGENTE DE SERVICOS RGERAIS                    1
# ENGENHEIRO MECANICO-ESPECIALIDADE             1
# CIRURGIAO DENTISTA                            1
# Name: cargo, Length: 917, dtype: int64

# %%
viagem['funcao'].value_counts()
# Out:
# -1            744104
# Sigilosa      109744
# Sargento         101
# Praças            68
# Suboficial        47
# OfSubalter        41
# OfSuperior        41
# OfIntermed        27
# DAS-1015          22
# DAS-1014          14
# DAS-1022          11
# FPE-1024          10
# CD-0004           10
# FCI-0001           9
# CNE-0001           8
# FGR-3              8
# FPE-1022           8
# DAS-1016           7
# FGR-1              7
# FG-0002            7
# NES-0008           7
# FG-0001            6
# CD-0003            6
# DAS-1011           6
# DAS-1024           6
# FUC-0001           5
# FG-0003            4
# DAS-1012           4
# DAS-1023           4
# FGR-2              4
# FPE-1014           4
# DAS-1013           3
# FG-0004            2
# DAS-1025           2
# FPE-1023           2
# FCD-2              2
# CD-0002            2
# Subtenente         1
# FCI-0002           1
# CD-0001            1
# FCT-13             1
# Of.General         1
# FG-0005            1
# FG-0007            1
# Name: funcao, dtype: int64

# %%
viagem['motivo'].value_counts()
# Out:
# Informação protegida por sigilo nos termos da legislação vigente                                                                                                                                                                                                                                                                                                                                             109744
# Jogos Olímpicos e Paralímpicos de 2016 - Simultânea.    Conforme Convênio de Cooperação Federativa, prestar apoio ao Departamento da Força Nacional de Segurança Pública e ao SENASP, na segurança interna e externa das instalações esportivas dos JOGOS OLÍMPICOS E PARAOLÍMPICOS RIO 2016.                                                                                                                  1715
# Jogos Olímpicos e Paralímpicos de 2016 - Simultânea.     Conforme Convênio de Cooperação Federativa, prestar apoio ao Departamento da Força Nacional de Segurança Pública e ao SENASP, na segurança interna e externa das instalações esportivas dos JOGOS OLÍMPICOS E PARAOLÍMPICOS RIO 2016.                                                                                                                 1512
# Jogos Olímpicos e Paralímpicos de 2016 - Simultânea.   Conforme Convênio de Cooperação Federativa, prestar apoio ao Departamento da Força Nacional de Segurança Pública e ao SENASP, na segurança interna e externa das instalações esportivas dos JOGOS OLÍMPICOS E PARAOLÍMPICOS RIO 2016.                                                                                                                    997
# MISSÃO DE TRANSPORTE DE AUTORIDADE. SC:01.44                                                                                                                                                                                                                                                                                                                                                                    953
#                                                                                                                                                                                                                                                                                                                                                                                                               ...
# DAR SUPORTE TÉCNICO DE ASSISTÊNCIA SOCIAL APS UBERLANDIA.                                                                                                                                                                                                                                                                                                                                                         1
# RESIDIR COMISSÃO DE SINDICANCIA PORTARIA 197 DE, 29.04.16 BS 18 DE 02.05.16                                                                                                                                                                                                                                                                                                                                       1
# PROCESSO RDC ÁREA DE VIVÊNCIA                                                                                                                                                                                                                                                                                                                                                                                     1
# MULHERES - Oficina com representantes da SES - AM e da Maternidade Balbina Mestrinho para o monitoramento do processo de implementação das ações de atenção humanizada ao abortamento e Reunião com a SMS de Manaus-AM. Esta agenda é de relevância para a CGSM devido à necessidade de apoiar a coordenação estadual de saúde da mulher e Balbina Mestrinho para qualificação da atenção ao abortamento.         1
# Reunião com o liquidante da Agraben que recebeu das administradoras de consórcio interessadas, em sua sede em Americana/SP, propostas objetivando a transferência as administração dos grupos de consórcios administrados pela liquidanda.                                                                                                                                                                        1
# Name: motivo, Length: 481483, dtype: int64

# %% [markdown]
# Filtrando - Orgão Solicitante:
#
# *   Departamento de Polícia Federal
# *   Instituto Nacional do Seguro Social

# %%
viagem = viagem[viagem['orgao_solicitante'].isin(['Departamento de Polícia Federal', 'Instituto Nacional do Seguro Social'])]

# %%
viagem.shape
# Out:
# (132799, 13)

# %%
viagem.describe()
# Out:
#           id_viagem  valor_diarias  valor_passagens  valor_devolucao  \
# count  1.327990e+05  132799.000000    132799.000000    132799.000000
# mean   1.296928e+07    1340.173250       208.260593        12.056909
# std    2.888989e+05    4076.734971       678.562638       165.485301
# min    1.246318e+07       0.000000         0.000000         0.000000
# 25%    1.272277e+07      67.680000         0.000000         0.000000
# 50%    1.295614e+07     259.260000         0.000000         0.000000
# 75%    1.322244e+07     734.040000         0.000000         0.000000
# max    1.367596e+07   79266.220000     25110.570000     27472.620000
#
#        valor_outros_ gastos    valor_total
# count         132799.000000  132799.000000
# mean              10.955538    1571.446290
# std               40.938319    4301.911498
# min                0.000000       0.000000
# 25%                0.000000      85.380000
# 50%                0.000000     280.080000
# 75%                0.000000     935.240000
# max             3061.420000   82690.830000

# %%
viagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132799 entries, 0 to 851244
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_viagem             132799 non-null  int64
#  1   orgao_solicitante     132799 non-null  object
#  2   nome                  132799 non-null  object
#  3   cargo                 132799 non-null  object
#  4   funcao                132799 non-null  object
#  5   data_ini              132799 non-null  object
#  6   data_fim              132799 non-null  object
#  7   motivo                132799 non-null  object
#  8   valor_diarias         132799 non-null  float64
#  9   valor_passagens       132799 non-null  float64
#  10  valor_devolucao       132799 non-null  float64
#  11  valor_outros_ gastos  132799 non-null  float64
#  12  valor_total           132799 non-null  float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 14.2+ MB

# %% [markdown]
# Identificando variável categórica que será o Alvo de nosso estudo.

# %%
viagem['orgao_solicitante'].value_counts()
# Out:
# Departamento de Polícia Federal        66990
# Instituto Nacional do Seguro Social    65809
# Name: orgao_solicitante, dtype: int64

# %% [markdown]
# Reduzido o DF de 12 para 6 colunas

# %%
df = viagem[['orgao_solicitante', 'valor_diarias', 'valor_passagens', 'valor_devolucao', 'valor_outros_ gastos', 'valor_total']]
df
# Out:
#                       orgao_solicitante  valor_diarias  valor_passagens  \
# 0       Departamento de Polícia Federal        8791.50              0.0
# 1       Departamento de Polícia Federal        6139.20              0.0
# 2       Departamento de Polícia Federal        1822.08              0.0
# 3       Departamento de Polícia Federal        1715.40              0.0
# 4       Departamento de Polícia Federal         919.45              0.0
# ...                                 ...            ...              ...
# 850941  Departamento de Polícia Federal         380.04              0.0
# 850943  Departamento de Polícia Federal         223.86              0.0
# 850944  Departamento de Polícia Federal         223.86              0.0
# 851243  Departamento de Polícia Federal         223.86              0.0
# 851244  Departamento de Polícia Federal         223.86              0.0
#
#         valor_devolucao  valor_outros_ gastos  valor_total
# 0                   0.0                   0.0      8791.50
# 1                   0.0                   0.0      6139.20
# 2                   0.0                   0.0      1822.08
# 3                   0.0                   0.0      1715.40
# 4                   0.0                   0.0       919.45
# ...                 ...                   ...          ...
# 850941              0.0                   0.0       380.04
# 850943              0.0                   0.0       223.86
# 850944              0.0                   0.0       223.86
# 851243              0.0                   0.0       223.86
# 851244              0.0                   0.0       223.86
#
# [132799 rows x 6 columns]

# %% [markdown]
# ## **Transformando as variáveis categóricas nominais em variáveis categóricas ordinais**
# Coluna orgao_solicitante

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df2 = pd.DataFrame.copy(df)

# %%
df2['orgao_solicitante'].replace({'Departamento de Polícia Federal': 0, 'Instituto Nacional do Seguro Social': 1}, inplace=True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132799 entries, 0 to 851244
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   orgao_solicitante     132799 non-null  int64
#  1   valor_diarias         132799 non-null  float64
#  2   valor_passagens       132799 non-null  float64
#  3   valor_devolucao       132799 non-null  float64
#  4   valor_outros_ gastos  132799 non-null  float64
#  5   valor_total           132799 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 7.1 MB

# %%
df['orgao_solicitante'] = df2['orgao_solicitante']
df.head()
# Out:
#    orgao_solicitante  valor_diarias  valor_passagens  valor_devolucao  \
# 0                  0        8791.50              0.0              0.0
# 1                  0        6139.20              0.0              0.0
# 2                  0        1822.08              0.0              0.0
# 3                  0        1715.40              0.0              0.0
# 4                  0         919.45              0.0              0.0
#
#    valor_outros_ gastos  valor_total
# 0                   0.0      8791.50
# 1                   0.0      6139.20
# 2                   0.0      1822.08
# 3                   0.0      1715.40
# 4                   0.0       919.45

# %%
df.dtypes
# Out:
# orgao_solicitante         int64
# valor_diarias           float64
# valor_passagens         float64
# valor_devolucao         float64
# valor_outros_ gastos    float64
# valor_total             float64
# dtype: object

# %% [markdown]
# ## **LEGENDA**

# %% [markdown]
# Orgao Solicitante = (0 = Departamento de Polícia Federal, 1 = Instituto Nacional do Seguro Social)
#
# valor_diarias = Valor gasto em diárias
#
# valor_passagens = Valor gasto com passagens
#
# valor_devolucao = Valor devolvido
#
# valor_outros_ gastos = Valor gasto com outros gastos
#
# valor_total = Gasto total

# %% [markdown]
# ## **ATRIBUTOS PREVISORES E ALVO**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132799 entries, 0 to 851244
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   orgao_solicitante     132799 non-null  int64
#  1   valor_diarias         132799 non-null  float64
#  2   valor_passagens       132799 non-null  float64
#  3   valor_devolucao       132799 non-null  float64
#  4   valor_outros_ gastos  132799 non-null  float64
#  5   valor_total           132799 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 7.1 MB

# %% [markdown]
# Previsores serão as colunas: valor_diarias, valor_passagens, valor_devolucao, valor_outros_ gastos, valor_total.

# %%
previsores = df.iloc[:, 1:5].values

# %%
previsores
# Out:
# array([[8791.5 ,    0.  ,    0.  ,    0.  ],
#        [6139.2 ,    0.  ,    0.  ,    0.  ],
#        [1822.08,    0.  ,    0.  ,    0.  ],
#        ...,
#        [ 223.86,    0.  ,    0.  ,    0.  ],
#        [ 223.86,    0.  ,    0.  ,    0.  ],
#        [ 223.86,    0.  ,    0.  ,    0.  ]])

# %%
previsores.shape
# Out:
# (132799, 4)

# %% [markdown]
# Alvo será a coluna orgao_solicitante.

# %%
alvo = df.iloc[:, 0].values

# %%
alvo
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
alvo.shape
# Out:
# (132799,)

# %% [markdown]
# ## **Análise das escalas dos atributos (Escalonamento)**

# %% [markdown]
# Padronização (utiliza a média e o desvio padrão como referência).

# %%
df.describe()
# Out:
#        orgao_solicitante  valor_diarias  valor_passagens  valor_devolucao  \
# count      132799.000000  132799.000000    132799.000000    132799.000000
# mean            0.495553    1340.173250       208.260593        12.056909
# std             0.499982    4076.734971       678.562638       165.485301
# min             0.000000       0.000000         0.000000         0.000000
# 25%             0.000000      67.680000         0.000000         0.000000
# 50%             0.000000     259.260000         0.000000         0.000000
# 75%             1.000000     734.040000         0.000000         0.000000
# max             1.000000   79266.220000     25110.570000     27472.620000
#
#        valor_outros_ gastos    valor_total
# count         132799.000000  132799.000000
# mean              10.955538    1571.446290
# std               40.938319    4301.911498
# min                0.000000       0.000000
# 25%                0.000000      85.380000
# 50%                0.000000     280.080000
# 75%                0.000000     935.240000
# max             3061.420000   82690.830000

# %%
from sklearn.preprocessing import StandardScaler

# %%
previsores_esc = StandardScaler().fit_transform(previsores)

# %%
previsores_esc
# Out:
# array([[ 1.82777513, -0.30691548, -0.07285816, -0.26761184],
#        [ 1.17717852, -0.30691548, -0.07285816, -0.26761184],
#        [ 0.11820944, -0.30691548, -0.07285816, -0.26761184],
#        ...,
#        [-0.27382635, -0.30691548, -0.07285816, -0.26761184],
#        [-0.27382635, -0.30691548, -0.07285816, -0.26761184],
#        [-0.27382635, -0.30691548, -0.07285816, -0.26761184]])

# %%
previsoresdf = pd.DataFrame(previsores_esc)
previsoresdf
# Out:
#                0         1         2         3
# 0       1.827775 -0.306915 -0.072858 -0.267612
# 1       1.177179 -0.306915 -0.072858 -0.267612
# 2       0.118209 -0.306915 -0.072858 -0.267612
# 3       0.092041 -0.306915 -0.072858 -0.267612
# 4      -0.103201 -0.306915 -0.072858 -0.267612
# ...          ...       ...       ...       ...
# 132794 -0.235516 -0.306915 -0.072858 -0.267612
# 132795 -0.273826 -0.306915 -0.072858 -0.267612
# 132796 -0.273826 -0.306915 -0.072858 -0.267612
# 132797 -0.273826 -0.306915 -0.072858 -0.267612
# 132798 -0.273826 -0.306915 -0.072858 -0.267612
#
# [132799 rows x 4 columns]

# %% [markdown]
# ## **RESUMO PRÉ-PROCESSAMENTO**

# %% [markdown]
# alvo = variável que se pretende atingir (orgao_solicitante).
#
# previsores = conjunto de variáveis previsoras com as variáveis categóricas transformadas em numéricas manualmente, sem escalonar.
#
# previsores_esc = conjunto de variáveis previsoras com as variáveis categóricas transformadas em numéricas, escalonada.

# %% [markdown]
# ## **BASE DE TREINO E TESTE**

# %% [markdown]
# Parâmetros train_test_split:
# - arrays: nomes dos atributos previsores e alvo.
# - test_size: tamanho em porcentagem dos dados de teste. default é none.
# - train_size: tamanho em porcentagem dos dados de treinamento.default é none.
# - random_state: nomeação de um estado aleatório.
# - shuffle: embaralhamento dos dados aleatórios. Associado com o random_state ocorre o mesmo embaralhamento sempre. Default é True.
# - stratify: Possibilidade de dividir os dados de forma estratificada. Default é None (nesse caso é mantido a proporção, isto é, se tem 30% de zeros e 70% de 1 no dataframe, na separação em treinamento e teste se manterá essa proporção).

# %%
from sklearn.model_selection import train_test_split

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(previsores_esc, alvo, test_size = 0.3, random_state = 0)

# %%
x_treino.shape
# Out:
# (92959, 4)

# %%
x_teste.shape
# Out:
# (39840, 4)

# %%
y_treino.shape
# Out:
# (92959,)

# %%
y_teste.shape
# Out:
# (39840,)

# %% [markdown]
# # **ÁRVORE DE DECISÃO**

# %% [markdown]
# ![max.png](data:image/png;base64,...)
# <br>Realizada diversas testagens do parâmetro max_depth, optou-se por utilizar o 25 que apresentou-se um melhor cenário de previsão.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
arvore = DecisionTreeClassifier(criterion='entropy', random_state = 0, max_depth=25)
_arvore = arvore.fit(x_treino, y_treino)
# max_depth é o parametro que poda a arvore. 
# ele equilibra o cenário de overfitting (chegando no best Fit) o ideal é ter uma acuracia parecida do treino e do teste.

# %%
tree.plot_tree(_arvore)
# Out:
# [Text(0.6892904565136416, 0.9807692307692307, 'X[3] <= -0.237\nentropy = 1.0\nsamples = 92959\nvalue = [46790, 46169]'),
#  Text(0.38774884142058574, 0.9423076923076923, 'X[0] <= -0.312\nentropy = 0.965\nsamples = 76332\nvalue = [46513, 29819]'),
#  Text(0.03841087849572497, 0.9038461538461539, 'X[0] <= -0.313\nentropy = 0.757\nsamples = 23099\nvalue = [5036, 18063]'),
#  Text(0.0243858823922337, 0.8653846153846154, 'X[1] <= -0.231\nentropy = 0.458\nsamples = 8925\nvalue = [862, 8063]'),
#  Text(0.008270339775561098, 0.8269230769230769, 'X[0] <= -0.318\nentropy = 0.213\nsamples = 8180\nvalue = [276, 7904]'),
#  Text(0.0014250089063056644, 0.7884615384615384, 'X[0] <= -0.32\nentropy = 0.078\nsamples = 5208\nvalue = [50, 5158]'),
#  Text(0.0007125044531528322, 0.75, 'X[0] <= -0.328\nentropy = 0.077\nsamples = 5172\nvalue = [49, 5123]'),
#  Text(0.0003562522265764161, 0.7115384615384616, 'entropy = 0.078\nsamples = 5078\nvalue = [49, 5029]'),
#  Text(0.0010687566797292483, 0.7115384615384616, 'entropy = 0.0\nsamples = 94\nvalue = [0, 94]'),
#  Text(0.0021375133594584966, 0.75, 'X[0] <= -0.32\nentropy = 0.183\nsamples = 36\nvalue = [1, 35]'),
#  Text(0.0017812611328820805, 0.7115384615384616, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0024937655860349127, 0.7115384615384616, 'entropy = 0.0\nsamples = 35\nvalue = [0, 35]'),
#  Text(0.01511567064481653, 0.7884615384615384, 'X[0] <= -0.314\nentropy = 0.388\nsamples = 2972\nvalue = [226, 2746]'),
#  Text(0.007074946562166014, 0.75, 'X[0] <= -0.316\nentropy = 0.794\nsamples = 560\nvalue = [134, 426]'),
#  Text(0.003206270039187745, 0.7115384615384616, 'X[0] <= -0.317\nentropy = 0.991\nsamples = 110\nvalue = [49, 61]'),
#  Text(0.0021375133594584966, 0.6730769230769231, 'X[0] <= -0.318\nentropy = 0.811\nsamples = 52\nvalue = [13, 39]'),
#  Text(0.0017812611328820805, 0.6346153846153846, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0024937655860349127, 0.6346153846153846, 'X[0] <= -0.318\nentropy = 0.511\nsamples = 44\nvalue = [5, 39]'),
#  Text(0.0017812611328820805, 0.5961538461538461, 'X[0] <= -0.318\nentropy = 0.811\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.0014250089063056644, 0.5576923076923077, 'X[0] <= -0.318\nentropy = 0.391\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.0010687566797292483, 0.5192307692307693, 'X[0] <= -0.318\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.0007125044531528322, 0.4807692307692308, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0014250089063056644, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0017812611328820805, 0.5192307692307693, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.0021375133594584966, 0.5576923076923077, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.003206270039187745, 0.5961538461538461, 'X[0] <= -0.317\nentropy = 0.222\nsamples = 28\nvalue = [1, 27]'),
#  Text(0.0028500178126113287, 0.5576923076923077, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.003562522265764161, 0.5576923076923077, 'X[0] <= -0.317\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.003206270039187745, 0.5192307692307693, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.003918774492340577, 0.5192307692307693, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.004275026718916993, 0.6730769230769231, 'X[0] <= -0.317\nentropy = 0.958\nsamples = 58\nvalue = [36, 22]'),
#  Text(0.003918774492340577, 0.6346153846153846, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.004631278945493409, 0.6346153846153846, 'X[0] <= -0.317\nentropy = 1.0\nsamples = 45\nvalue = [23, 22]'),
#  Text(0.004275026718916993, 0.5961538461538461, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.004987531172069825, 0.5961538461538461, 'X[0] <= -0.317\nentropy = 0.968\nsamples = 38\nvalue = [23, 15]'),
#  Text(0.004631278945493409, 0.5576923076923077, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.005343783398646241, 0.5576923076923077, 'X[0] <= -0.317\nentropy = 0.997\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.004631278945493409, 0.5192307692307693, 'X[0] <= -0.317\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.004275026718916993, 0.4807692307692308, 'X[0] <= -0.317\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.003918774492340577, 0.4423076923076923, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.004631278945493409, 0.4423076923076923, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.004987531172069825, 0.4807692307692308, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.006056287851799074, 0.5192307692307693, 'X[0] <= -0.317\nentropy = 0.792\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.0057000356252226575, 0.4807692307692308, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.00641254007837549, 0.4807692307692308, 'X[0] <= -0.317\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.006056287851799074, 0.4423076923076923, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.006768792304951906, 0.4423076923076923, 'X[0] <= -0.316\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.00641254007837549, 0.40384615384615385, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.007125044531528322, 0.40384615384615385, 'X[0] <= -0.316\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.006768792304951906, 0.36538461538461536, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.007481296758104738, 0.36538461538461536, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.010943623085144282, 0.7115384615384616, 'X[0] <= -0.316\nentropy = 0.699\nsamples = 450\nvalue = [85, 365]'),
#  Text(0.009618810117563235, 0.6730769230769231, 'X[0] <= -0.316\nentropy = 0.337\nsamples = 48\nvalue = [3, 45]'),
#  Text(0.009262557890986818, 0.6346153846153846, 'X[0] <= -0.316\nentropy = 0.459\nsamples = 31\nvalue = [3, 28]'),
#  Text(0.008906305664410403, 0.5961538461538461, 'X[0] <= -0.316\nentropy = 0.353\nsamples = 30\nvalue = [2, 28]'),
#  Text(0.008550053437833986, 0.5576923076923077, 'X[0] <= -0.316\nentropy = 0.544\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.008193801211257571, 0.5192307692307693, 'X[0] <= -0.316\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.007837548984681154, 0.4807692307692308, 'X[0] <= -0.316\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.007481296758104738, 0.4423076923076923, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.008193801211257571, 0.4423076923076923, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.008550053437833986, 0.4807692307692308, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.008906305664410403, 0.5192307692307693, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.009262557890986818, 0.5576923076923077, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.009618810117563235, 0.5961538461538461, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.00997506234413965, 0.6346153846153846, 'entropy = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.01226843605272533, 0.6730769230769231, 'X[0] <= -0.315\nentropy = 0.73\nsamples = 402\nvalue = [82, 320]'),
#  Text(0.010687566797292483, 0.6346153846153846, 'X[0] <= -0.315\nentropy = 0.999\nsamples = 31\nvalue = [16, 15]'),
#  Text(0.010331314570716068, 0.5961538461538461, 'X[0] <= -0.315\nentropy = 0.902\nsamples = 22\nvalue = [7, 15]'),
#  Text(0.00997506234413965, 0.5576923076923077, 'X[0] <= -0.316\nentropy = 0.98\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.009618810117563235, 0.5192307692307693, 'X[0] <= -0.316\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.009262557890986818, 0.4807692307692308, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.00997506234413965, 0.4807692307692308, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.010331314570716068, 0.5192307692307693, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.010687566797292483, 0.5576923076923077, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.0110438190238689, 0.5961538461538461, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.013849305308158175, 0.6346153846153846, 'X[0] <= -0.315\nentropy = 0.675\nsamples = 371\nvalue = [66, 305]'),
#  Text(0.012112575703598147, 0.5961538461538461, 'X[0] <= -0.315\nentropy = 0.31\nsamples = 54\nvalue = [3, 51]'),
#  Text(0.011400071250445315, 0.5576923076923077, 'X[0] <= -0.315\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.0110438190238689, 0.5192307692307693, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.011756323477021732, 0.5192307692307693, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01282508015675098, 0.5576923076923077, 'X[0] <= -0.315\nentropy = 0.149\nsamples = 47\nvalue = [1, 46]'),
#  Text(0.012468827930174564, 0.5192307692307693, 'entropy = 0.0\nsamples = 37\nvalue = [0, 37]'),
#  Text(0.013181332383327396, 0.5192307692307693, 'X[0] <= -0.315\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.01282508015675098, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.013537584609903812, 0.4807692307692308, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.015586034912718205, 0.5961538461538461, 'X[0] <= -0.315\nentropy = 0.719\nsamples = 317\nvalue = [63, 254]'),
#  Text(0.015229782686141788, 0.5576923076923077, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.01594228713929462, 0.5576923076923077, 'X[0] <= -0.314\nentropy = 0.681\nsamples = 310\nvalue = [56, 254]'),
#  Text(0.015586034912718205, 0.5192307692307693, 'X[0] <= -0.314\nentropy = 0.67\nsamples = 308\nvalue = [54, 254]'),
#  Text(0.014250089063056644, 0.4807692307692308, 'X[0] <= -0.314\nentropy = 0.738\nsamples = 192\nvalue = [40, 152]'),
#  Text(0.013359458496615604, 0.4423076923076923, 'X[0] <= -0.314\nentropy = 0.568\nsamples = 127\nvalue = [17, 110]'),
#  Text(0.013003206270039187, 0.40384615384615385, 'X[0] <= -0.314\nentropy = 0.794\nsamples = 71\nvalue = [17, 54]'),
#  Text(0.012646954043462772, 0.36538461538461536, 'X[0] <= -0.315\nentropy = 0.755\nsamples = 69\nvalue = [15, 54]'),
#  Text(0.012290701816886355, 0.3269230769230769, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.013003206270039187, 0.3269230769230769, 'X[0] <= -0.315\nentropy = 0.805\nsamples = 61\nvalue = [15, 46]'),
#  Text(0.011756323477021732, 0.28846153846153844, 'X[0] <= -0.315\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.011400071250445315, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.012112575703598147, 0.25, 'X[0] <= -0.315\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.011756323477021732, 0.21153846153846154, 'X[0] <= -0.315\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.011400071250445315, 0.17307692307692307, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.012112575703598147, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012468827930174564, 0.21153846153846154, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.014250089063056644, 0.28846153846153844, 'X[0] <= -0.314\nentropy = 0.657\nsamples = 53\nvalue = [9, 44]'),
#  Text(0.013537584609903812, 0.25, 'X[0] <= -0.315\nentropy = 0.337\nsamples = 32\nvalue = [2, 30]'),
#  Text(0.013181332383327396, 0.21153846153846154, 'X[0] <= -0.315\nentropy = 0.523\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.01282508015675098, 0.17307692307692307, 'X[0] <= -0.315\nentropy = 0.337\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.012468827930174564, 0.1346153846153846, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.013181332383327396, 0.1346153846153846, 'X[0] <= -0.315\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.01282508015675098, 0.09615384615384616, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.013537584609903812, 0.09615384615384616, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.013537584609903812, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.013893836836480229, 0.21153846153846154, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.014962593516209476, 0.25, 'X[0] <= -0.314\nentropy = 0.918\nsamples = 21\nvalue = [7, 14]'),
#  Text(0.01460634128963306, 0.21153846153846154, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.015318845742785893, 0.21153846153846154, 'X[0] <= -0.314\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.014962593516209476, 0.17307692307692307, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.015675097969362308, 0.17307692307692307, 'X[0] <= -0.314\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.015318845742785893, 0.1346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016031350195938723, 0.1346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013359458496615604, 0.36538461538461536, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01371571072319202, 0.40384615384615385, 'entropy = 0.0\nsamples = 56\nvalue = [0, 56]'),
#  Text(0.015140719629497684, 0.4423076923076923, 'X[0] <= -0.314\nentropy = 0.937\nsamples = 65\nvalue = [23, 42]'),
#  Text(0.014428215176344851, 0.40384615384615385, 'X[2] <= -0.061\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.014071962949768436, 0.36538461538461536, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.014784467402921268, 0.36538461538461536, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015853224082650517, 0.40384615384615385, 'X[0] <= -0.314\nentropy = 0.68\nsamples = 50\nvalue = [9, 41]'),
#  Text(0.0154969718560741, 0.36538461538461536, 'entropy = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.016209476309226933, 0.36538461538461536, 'X[0] <= -0.314\nentropy = 0.966\nsamples = 23\nvalue = [9, 14]'),
#  Text(0.015853224082650517, 0.3269230769230769, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.016565728535803348, 0.3269230769230769, 'X[0] <= -0.314\nentropy = 0.672\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.016209476309226933, 0.28846153846153844, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.016921980762379763, 0.28846153846153844, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.016921980762379763, 0.4807692307692308, 'X[0] <= -0.314\nentropy = 0.531\nsamples = 116\nvalue = [14, 102]'),
#  Text(0.016565728535803348, 0.4423076923076923, 'entropy = 0.0\nsamples = 61\nvalue = [0, 61]'),
#  Text(0.017278232988956182, 0.4423076923076923, 'X[0] <= -0.314\nentropy = 0.818\nsamples = 55\nvalue = [14, 41]'),
#  Text(0.016921980762379763, 0.40384615384615385, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.017634485215532597, 0.40384615384615385, 'X[0] <= -0.314\nentropy = 0.714\nsamples = 51\nvalue = [10, 41]'),
#  Text(0.017278232988956182, 0.36538461538461536, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.017990737442109012, 0.36538461538461536, 'X[0] <= -0.314\nentropy = 0.831\nsamples = 38\nvalue = [10, 28]'),
#  Text(0.017634485215532597, 0.3269230769230769, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.01834698966868543, 0.3269230769230769, 'X[0] <= -0.314\nentropy = 0.614\nsamples = 33\nvalue = [5, 28]'),
#  Text(0.017634485215532597, 0.28846153846153844, 'X[0] <= -0.314\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.017278232988956182, 0.25, 'X[0] <= -0.314\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.016921980762379763, 0.21153846153846154, 'X[0] <= -0.314\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.016565728535803348, 0.17307692307692307, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.017278232988956182, 0.17307692307692307, 'X[0] <= -0.314\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.016921980762379763, 0.1346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.017634485215532597, 0.1346153846153846, 'X[0] <= -0.314\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.017278232988956182, 0.09615384615384616, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.017990737442109012, 0.09615384615384616, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.017634485215532597, 0.21153846153846154, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.017990737442109012, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01905949412183826, 0.28846153846153844, 'X[0] <= -0.314\nentropy = 0.276\nsamples = 21\nvalue = [1, 20]'),
#  Text(0.018703241895261846, 0.25, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.019415746348414677, 0.25, 'X[0] <= -0.314\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.01905949412183826, 0.21153846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.019771998574991095, 0.21153846153846154, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.016298539365871036, 0.5192307692307693, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.023156394727467045, 0.75, 'X[0] <= -0.313\nentropy = 0.234\nsamples = 2412\nvalue = [92, 2320]'),
#  Text(0.02119700748129676, 0.7115384615384616, 'X[0] <= -0.314\nentropy = 0.059\nsamples = 1323\nvalue = [9, 1314]'),
#  Text(0.020484503028143926, 0.6730769230769231, 'X[0] <= -0.314\nentropy = 0.289\nsamples = 99\nvalue = [5, 94]'),
#  Text(0.02012825080156751, 0.6346153846153846, 'X[0] <= -0.314\nentropy = 0.246\nsamples = 98\nvalue = [4, 94]'),
#  Text(0.019771998574991095, 0.5961538461538461, 'X[0] <= -0.314\nentropy = 0.353\nsamples = 60\nvalue = [4, 56]'),
#  Text(0.019415746348414677, 0.5576923076923077, 'X[0] <= -0.314\nentropy = 0.216\nsamples = 58\nvalue = [2, 56]'),
#  Text(0.018703241895261846, 0.5192307692307693, 'X[0] <= -0.314\nentropy = 0.133\nsamples = 54\nvalue = [1, 53]'),
#  Text(0.01834698966868543, 0.4807692307692308, 'X[0] <= -0.314\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.017990737442109012, 0.4423076923076923, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.018703241895261846, 0.4423076923076923, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01905949412183826, 0.4807692307692308, 'entropy = 0.0\nsamples = 42\nvalue = [0, 42]'),
#  Text(0.02012825080156751, 0.5192307692307693, 'X[0] <= -0.314\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.019771998574991095, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.020484503028143926, 0.4807692307692308, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.02012825080156751, 0.5576923076923077, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.020484503028143926, 0.5961538461538461, 'entropy = 0.0\nsamples = 38\nvalue = [0, 38]'),
#  Text(0.02084075525472034, 0.6346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.02190951193444959, 0.6730769230769231, 'X[0] <= -0.313\nentropy = 0.032\nsamples = 1224\nvalue = [4, 1220]'),
#  Text(0.021553259707873175, 0.6346153846153846, 'entropy = 0.0\nsamples = 514\nvalue = [0, 514]'),
#  Text(0.022265764161026005, 0.6346153846153846, 'X[0] <= -0.313\nentropy = 0.05\nsamples = 710\nvalue = [4, 706]'),
#  Text(0.021553259707873175, 0.5961538461538461, 'X[2] <= 0.119\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.02119700748129676, 0.5576923076923077, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.02190951193444959, 0.5576923076923077, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02297826861417884, 0.5961538461538461, 'X[0] <= -0.313\nentropy = 0.04\nsamples = 707\nvalue = [3, 704]'),
#  Text(0.022622016387602424, 0.5576923076923077, 'entropy = 0.0\nsamples = 395\nvalue = [0, 395]'),
#  Text(0.023334520840755255, 0.5576923076923077, 'X[0] <= -0.313\nentropy = 0.078\nsamples = 312\nvalue = [3, 309]'),
#  Text(0.02297826861417884, 0.5192307692307693, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.02369077306733167, 0.5192307692307693, 'X[0] <= -0.313\nentropy = 0.032\nsamples = 308\nvalue = [1, 307]'),
#  Text(0.023334520840755255, 0.4807692307692308, 'entropy = 0.0\nsamples = 180\nvalue = [0, 180]'),
#  Text(0.02404702529390809, 0.4807692307692308, 'X[0] <= -0.313\nentropy = 0.066\nsamples = 128\nvalue = [1, 127]'),
#  Text(0.02369077306733167, 0.4423076923076923, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.024403277520484504, 0.4423076923076923, 'entropy = 0.0\nsamples = 127\nvalue = [0, 127]'),
#  Text(0.025115781973637334, 0.7115384615384616, 'X[0] <= -0.313\nentropy = 0.389\nsamples = 1089\nvalue = [83, 1006]'),
#  Text(0.024403277520484504, 0.6730769230769231, 'X[0] <= -0.313\nentropy = 0.993\nsamples = 102\nvalue = [46, 56]'),
#  Text(0.02404702529390809, 0.6346153846153846, 'X[0] <= -0.313\nentropy = 0.358\nsamples = 59\nvalue = [4, 55]'),
#  Text(0.02369077306733167, 0.5961538461538461, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.024403277520484504, 0.5961538461538461, 'entropy = 0.0\nsamples = 55\nvalue = [0, 55]'),
#  Text(0.02475952974706092, 0.6346153846153846, 'entropy = 0.159\nsamples = 43\nvalue = [42, 1]'),
#  Text(0.025828286426790168, 0.6730769230769231, 'X[0] <= -0.313\nentropy = 0.231\nsamples = 987\nvalue = [37, 950]'),
#  Text(0.025472034200213753, 0.6346153846153846, 'entropy = 0.0\nsamples = 253\nvalue = [0, 253]'),
#  Text(0.026184538653366583, 0.6346153846153846, 'X[0] <= -0.313\nentropy = 0.288\nsamples = 734\nvalue = [37, 697]'),
#  Text(0.025828286426790168, 0.5961538461538461, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.026540790879943, 0.5961538461538461, 'X[0] <= -0.313\nentropy = 0.191\nsamples = 718\nvalue = [21, 697]'),
#  Text(0.025115781973637334, 0.5576923076923077, 'X[0] <= -0.313\nentropy = 0.062\nsamples = 550\nvalue = [4, 546]'),
#  Text(0.02475952974706092, 0.5192307692307693, 'entropy = 0.0\nsamples = 160\nvalue = [0, 160]'),
#  Text(0.025472034200213753, 0.5192307692307693, 'X[0] <= -0.313\nentropy = 0.082\nsamples = 390\nvalue = [4, 386]'),
#  Text(0.025115781973637334, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.025828286426790168, 0.4807692307692308, 'X[0] <= -0.313\nentropy = 0.065\nsamples = 389\nvalue = [3, 386]'),
#  Text(0.025472034200213753, 0.4423076923076923, 'entropy = 0.0\nsamples = 137\nvalue = [0, 137]'),
#  Text(0.026184538653366583, 0.4423076923076923, 'X[0] <= -0.313\nentropy = 0.093\nsamples = 252\nvalue = [3, 249]'),
#  Text(0.025828286426790168, 0.40384615384615385, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.026540790879943, 0.40384615384615385, 'X[0] <= -0.313\nentropy = 0.068\nsamples = 247\nvalue = [2, 245]'),
#  Text(0.026184538653366583, 0.36538461538461536, 'entropy = 0.0\nsamples = 154\nvalue = [0, 154]'),
#  Text(0.026897043106519417, 0.36538461538461536, 'X[0] <= -0.313\nentropy = 0.15\nsamples = 93\nvalue = [2, 91]'),
#  Text(0.026540790879943, 0.3269230769230769, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.027253295333095832, 0.3269230769230769, 'entropy = 0.0\nsamples = 91\nvalue = [0, 91]'),
#  Text(0.027965799786248663, 0.5576923076923077, 'X[0] <= -0.313\nentropy = 0.473\nsamples = 168\nvalue = [17, 151]'),
#  Text(0.027609547559672248, 0.5192307692307693, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.02832205201282508, 0.5192307692307693, 'X[0] <= -0.313\nentropy = 0.173\nsamples = 155\nvalue = [4, 151]'),
#  Text(0.027965799786248663, 0.4807692307692308, 'X[0] <= -0.313\nentropy = 0.367\nsamples = 57\nvalue = [4, 53]'),
#  Text(0.027609547559672248, 0.4423076923076923, 'X[0] <= -0.313\nentropy = 0.133\nsamples = 54\nvalue = [1, 53]'),
#  Text(0.027253295333095832, 0.40384615384615385, 'entropy = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.027965799786248663, 0.40384615384615385, 'X[0] <= -0.313\nentropy = 0.25\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.027609547559672248, 0.36538461538461536, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.02832205201282508, 0.36538461538461536, 'entropy = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.02832205201282508, 0.4423076923076923, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.028678304239401497, 0.4807692307692308, 'entropy = 0.0\nsamples = 98\nvalue = [0, 98]'),
#  Text(0.04050142500890631, 0.8269230769230769, 'X[1] <= 5.077\nentropy = 0.748\nsamples = 745\nvalue = [586, 159]'),
#  Text(0.04014517278232989, 0.7884615384615384, 'X[1] <= 2.749\nentropy = 0.77\nsamples = 706\nvalue = [547, 159]'),
#  Text(0.03529123619522622, 0.75, 'X[1] <= 2.206\nentropy = 0.79\nsamples = 628\nvalue = [479, 149]'),
#  Text(0.032708407552547204, 0.7115384615384616, 'X[1] <= 1.99\nentropy = 0.767\nsamples = 581\nvalue = [451, 130]'),
#  Text(0.03181777698610616, 0.6730769230769231, 'X[1] <= 1.97\nentropy = 0.779\nsamples = 555\nvalue = [427, 128]'),
#  Text(0.03146152475952975, 0.6346153846153846, 'X[1] <= -0.115\nentropy = 0.777\nsamples = 554\nvalue = [427, 127]'),
#  Text(0.03110527253295333, 0.5961538461538461, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03181777698610616, 0.5961538461538461, 'X[1] <= -0.099\nentropy = 0.78\nsamples = 550\nvalue = [423, 127]'),
#  Text(0.03146152475952975, 0.5576923076923077, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03217402921268258, 0.5576923076923077, 'X[1] <= 0.054\nentropy = 0.775\nsamples = 548\nvalue = [423, 125]'),
#  Text(0.03146152475952975, 0.5192307692307693, 'X[1] <= -0.077\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.03110527253295333, 0.4807692307692308, 'X[1] <= -0.088\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.030749020306376915, 0.4423076923076923, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03146152475952975, 0.4423076923076923, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03181777698610616, 0.4807692307692308, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.03288653366583541, 0.5192307692307693, 'X[1] <= 0.058\nentropy = 0.783\nsamples = 532\nvalue = [408, 124]'),
#  Text(0.032530281439259, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03324278589241183, 0.4807692307692308, 'X[1] <= 1.942\nentropy = 0.781\nsamples = 531\nvalue = [408, 123]'),
#  Text(0.03288653366583541, 0.4423076923076923, 'X[1] <= 1.936\nentropy = 0.784\nsamples = 527\nvalue = [404, 123]'),
#  Text(0.032530281439259, 0.40384615384615385, 'X[1] <= 1.02\nentropy = 0.781\nsamples = 526\nvalue = [404, 122]'),
#  Text(0.029390808692554327, 0.36538461538461536, 'X[1] <= 0.987\nentropy = 0.814\nsamples = 302\nvalue = [226, 76]'),
#  Text(0.027965799786248663, 0.3269230769230769, 'X[1] <= 0.939\nentropy = 0.787\nsamples = 289\nvalue = [221, 68]'),
#  Text(0.027253295333095832, 0.28846153846153844, 'X[1] <= 0.929\nentropy = 0.8\nsamples = 276\nvalue = [209, 67]'),
#  Text(0.026897043106519417, 0.25, 'X[1] <= 0.916\nentropy = 0.79\nsamples = 274\nvalue = [209, 65]'),
#  Text(0.026540790879943, 0.21153846153846154, 'X[1] <= 0.914\nentropy = 0.796\nsamples = 270\nvalue = [205, 65]'),
#  Text(0.026184538653366583, 0.17307692307692307, 'X[1] <= 0.21\nentropy = 0.792\nsamples = 269\nvalue = [205, 64]'),
#  Text(0.02502671891699323, 0.1346153846153846, 'X[1] <= 0.183\nentropy = 0.658\nsamples = 47\nvalue = [39, 8]'),
#  Text(0.024670466690416816, 0.09615384615384616, 'X[1] <= 0.177\nentropy = 0.742\nsamples = 38\nvalue = [30, 8]'),
#  Text(0.024314214463840397, 0.057692307692307696, 'X[1] <= 0.096\nentropy = 0.7\nsamples = 37\nvalue = [30, 7]'),
#  Text(0.023957962237263982, 0.019230769230769232, 'entropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.024670466690416816, 0.019230769230769232, 'entropy = 0.592\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.02502671891699323, 0.057692307692307696, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.025382971143569646, 0.09615384615384616, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.027342358389739935, 0.1346153846153846, 'X[1] <= 0.358\nentropy = 0.815\nsamples = 222\nvalue = [166, 56]'),
#  Text(0.026451727823298896, 0.09615384615384616, 'X[1] <= 0.326\nentropy = 0.985\nsamples = 35\nvalue = [20, 15]'),
#  Text(0.02573922337014606, 0.057692307692307696, 'X[1] <= 0.214\nentropy = 0.828\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.025382971143569646, 0.019230769230769232, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02609547559672248, 0.019230769230769232, 'entropy = 0.773\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.02716423227645173, 0.057692307692307696, 'X[1] <= 0.337\nentropy = 0.811\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.02680798004987531, 0.019230769230769232, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.027520484503028145, 0.019230769230769232, 'entropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.028232988956180975, 0.09615384615384616, 'X[1] <= 0.382\nentropy = 0.759\nsamples = 187\nvalue = [146, 41]'),
#  Text(0.02787673672960456, 0.057692307692307696, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.028589241182757394, 0.057692307692307696, 'X[1] <= 0.386\nentropy = 0.779\nsamples = 178\nvalue = [137, 41]'),
#  Text(0.028232988956180975, 0.019230769230769232, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.02894549340933381, 0.019230769230769232, 'entropy = 0.763\nsamples = 176\nvalue = [137, 39]'),
#  Text(0.026897043106519417, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.027253295333095832, 0.21153846153846154, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.027609547559672248, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.028678304239401497, 0.28846153846153844, 'X[1] <= 0.967\nentropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.02832205201282508, 0.25, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.029034556465977912, 0.25, 'X[1] <= 0.976\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.028678304239401497, 0.21153846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.029390808692554327, 0.21153846153846154, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03081581759885999, 0.3269230769230769, 'X[1] <= 0.995\nentropy = 0.961\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.030459565372283576, 0.28846153846153844, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.03117206982543641, 0.28846153846153844, 'X[1] <= 1.009\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.030459565372283576, 0.25, 'X[1] <= 1.004\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.03010331314570716, 0.21153846153846154, 'X[1] <= 1.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.029747060919130746, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.030459565372283576, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03081581759885999, 0.21153846153846154, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03188457427858924, 0.25, 'X[1] <= 1.011\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.03152832205201282, 0.21153846153846154, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03224082650516566, 0.21153846153846154, 'X[1] <= 1.015\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03188457427858924, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03259707873174207, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03566975418596366, 0.36538461538461536, 'X[1] <= 1.149\nentropy = 0.733\nsamples = 224\nvalue = [178, 46]'),
#  Text(0.034556465977912364, 0.3269230769230769, 'X[1] <= 1.101\nentropy = 0.154\nsamples = 45\nvalue = [44, 1]'),
#  Text(0.034200213751335945, 0.28846153846153844, 'entropy = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.034912718204488775, 0.28846153846153844, 'X[1] <= 1.104\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.034556465977912364, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.035268970431065194, 0.25, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.03678304239401496, 0.3269230769230769, 'X[1] <= 1.155\nentropy = 0.813\nsamples = 179\nvalue = [134, 45]'),
#  Text(0.03642679016743855, 0.28846153846153844, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03713929462059138, 0.28846153846153844, 'X[1] <= 1.902\nentropy = 0.8\nsamples = 177\nvalue = [134, 43]'),
#  Text(0.035981474884218025, 0.25, 'X[1] <= 1.779\nentropy = 0.787\nsamples = 170\nvalue = [130, 40]'),
#  Text(0.03473459209120057, 0.21153846153846154, 'X[1] <= 1.739\nentropy = 0.814\nsamples = 155\nvalue = [116, 39]'),
#  Text(0.03330958318489491, 0.17307692307692307, 'X[1] <= 1.568\nentropy = 0.786\nsamples = 149\nvalue = [114, 35]'),
#  Text(0.03188457427858924, 0.1346153846153846, 'X[1] <= 1.564\nentropy = 0.838\nsamples = 112\nvalue = [82, 30]'),
#  Text(0.03152832205201282, 0.09615384615384616, 'X[1] <= 1.456\nentropy = 0.829\nsamples = 111\nvalue = [82, 29]'),
#  Text(0.03081581759885999, 0.057692307692307696, 'X[1] <= 1.402\nentropy = 0.779\nsamples = 78\nvalue = [60, 18]'),
#  Text(0.030459565372283576, 0.019230769230769232, 'entropy = 0.866\nsamples = 59\nvalue = [42, 17]'),
#  Text(0.03117206982543641, 0.019230769230769232, 'entropy = 0.297\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.03224082650516566, 0.057692307692307696, 'X[1] <= 1.476\nentropy = 0.918\nsamples = 33\nvalue = [22, 11]'),
#  Text(0.03188457427858924, 0.019230769230769232, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.03259707873174207, 0.019230769230769232, 'entropy = 0.797\nsamples = 29\nvalue = [22, 7]'),
#  Text(0.03224082650516566, 0.09615384615384616, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03473459209120057, 0.1346153846153846, 'X[1] <= 1.636\nentropy = 0.571\nsamples = 37\nvalue = [32, 5]'),
#  Text(0.03402208763804774, 0.09615384615384616, 'X[1] <= 1.597\nentropy = 0.31\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.03366583541147132, 0.057692307692307696, 'X[1] <= 1.593\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.03330958318489491, 0.019230769230769232, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.03402208763804774, 0.019230769230769232, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03437833986462415, 0.057692307692307696, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.0354470965443534, 0.09615384615384616, 'X[1] <= 1.645\nentropy = 0.742\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.03509084431777699, 0.057692307692307696, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03580334877092982, 0.057692307692307696, 'X[1] <= 1.673\nentropy = 0.65\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.0354470965443534, 0.019230769230769232, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.03615960099750624, 0.019230769230769232, 'entropy = 0.811\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.03615960099750624, 0.17307692307692307, 'X[1] <= 1.76\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03580334877092982, 0.1346153846153846, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.03651585322408265, 0.1346153846153846, 'X[1] <= 1.773\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03615960099750624, 0.09615384615384616, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03687210545065907, 0.09615384615384616, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03722835767723548, 0.21153846153846154, 'X[1] <= 1.848\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.03687210545065907, 0.17307692307692307, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.0375846099038119, 0.17307692307692307, 'X[1] <= 1.867\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.03722835767723548, 0.1346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03794086213038832, 0.1346153846153846, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.03829711435696473, 0.25, 'X[1] <= 1.909\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.03794086213038832, 0.21153846153846154, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03865336658354115, 0.21153846153846154, 'X[1] <= 1.925\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.03829711435696473, 0.17307692307692307, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.039009618810117566, 0.17307692307692307, 'X[1] <= 1.927\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03865336658354115, 0.1346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03936587103669398, 0.1346153846153846, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03324278589241183, 0.40384615384615385, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03359903811898824, 0.4423076923076923, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03217402921268258, 0.6346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03359903811898824, 0.6730769230769231, 'X[1] <= 2.107\nentropy = 0.391\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.03324278589241183, 0.6346153846153846, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.03395529034556466, 0.6346153846153846, 'X[1] <= 2.111\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.03359903811898824, 0.5961538461538461, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03431154257214108, 0.5961538461538461, 'X[1] <= 2.139\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.03395529034556466, 0.5576923076923077, 'X[1] <= 2.13\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.03359903811898824, 0.5192307692307693, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03431154257214108, 0.5192307692307693, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03466779479871749, 0.5576923076923077, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.03787406483790524, 0.7115384615384616, 'X[1] <= 2.36\nentropy = 0.973\nsamples = 47\nvalue = [28, 19]'),
#  Text(0.03680530815817599, 0.6730769230769231, 'X[1] <= 2.311\nentropy = 0.954\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.03644905593159957, 0.6346153846153846, 'X[1] <= 2.29\nentropy = 0.985\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.03609280370502316, 0.5961538461538461, 'X[1] <= 2.214\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.03538029925187033, 0.5576923076923077, 'X[1] <= 2.211\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03502404702529391, 0.5192307692307693, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03573655147844674, 0.5192307692307693, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03680530815817599, 0.5576923076923077, 'X[1] <= 2.256\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.03644905593159957, 0.5192307692307693, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.03716156038475241, 0.5192307692307693, 'X[1] <= 2.26\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03680530815817599, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03751781261132882, 0.4807692307692308, 'X[1] <= 2.272\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.03716156038475241, 0.4423076923076923, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.03787406483790524, 0.4423076923076923, 'X[1] <= 2.277\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03751781261132882, 0.40384615384615385, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.038230317064481656, 0.40384615384615385, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03680530815817599, 0.5961538461538461, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03716156038475241, 0.6346153846153846, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.038942821517634486, 0.6730769230769231, 'X[1] <= 2.488\nentropy = 0.869\nsamples = 31\nvalue = [22, 9]'),
#  Text(0.038230317064481656, 0.6346153846153846, 'X[1] <= 2.407\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.03787406483790524, 0.5961538461538461, 'X[1] <= 2.384\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03751781261132882, 0.5576923076923077, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.038230317064481656, 0.5576923076923077, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03858656929105807, 0.5961538461538461, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.03965532597078732, 0.6346153846153846, 'X[1] <= 2.498\nentropy = 0.982\nsamples = 19\nvalue = [11, 8]'),
#  Text(0.0392990737442109, 0.5961538461538461, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.040011578197363735, 0.5961538461538461, 'X[1] <= 2.586\nentropy = 0.964\nsamples = 18\nvalue = [11, 7]'),
#  Text(0.0392990737442109, 0.5576923076923077, 'X[1] <= 2.523\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.038942821517634486, 0.5192307692307693, 'X[1] <= 2.513\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03858656929105807, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0392990737442109, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03965532597078732, 0.5192307692307693, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.040724082650516566, 0.5576923076923077, 'X[1] <= 2.602\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.04036783042394015, 0.5192307692307693, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.041080334877092985, 0.5192307692307693, 'X[1] <= 2.613\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.040724082650516566, 0.4807692307692308, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.041436587103669396, 0.4807692307692308, 'X[1] <= 2.666\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.041080334877092985, 0.4423076923076923, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.041792839330245815, 0.4423076923076923, 'X[1] <= 2.741\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.041436587103669396, 0.40384615384615385, 'X[1] <= 2.693\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.041080334877092985, 0.36538461538461536, 'X[1] <= 2.673\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.040724082650516566, 0.3269230769230769, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.041436587103669396, 0.3269230769230769, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.041792839330245815, 0.36538461538461536, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.04214909155682223, 0.40384615384615385, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.044999109369433556, 0.75, 'X[1] <= 4.981\nentropy = 0.552\nsamples = 78\nvalue = [68, 10]'),
#  Text(0.044642857142857144, 0.7115384615384616, 'X[1] <= 2.912\nentropy = 0.52\nsamples = 77\nvalue = [68, 9]'),
#  Text(0.044286604916280725, 0.6730769230769231, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.044999109369433556, 0.6730769230769231, 'X[1] <= 2.922\nentropy = 0.586\nsamples = 64\nvalue = [55, 9]'),
#  Text(0.044642857142857144, 0.6346153846153846, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.045355361596009974, 0.6346153846153846, 'X[1] <= 4.438\nentropy = 0.549\nsamples = 63\nvalue = [55, 8]'),
#  Text(0.044999109369433556, 0.5961538461538461, 'X[1] <= 4.341\nentropy = 0.619\nsamples = 52\nvalue = [44, 8]'),
#  Text(0.044642857142857144, 0.5576923076923077, 'X[1] <= 4.033\nentropy = 0.529\nsamples = 50\nvalue = [44, 6]'),
#  Text(0.044286604916280725, 0.5192307692307693, 'X[1] <= 3.933\nentropy = 0.592\nsamples = 42\nvalue = [36, 6]'),
#  Text(0.04393035268970431, 0.4807692307692308, 'X[1] <= 3.158\nentropy = 0.535\nsamples = 41\nvalue = [36, 5]'),
#  Text(0.043217848236551476, 0.4423076923076923, 'X[1] <= 3.115\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.042861596009975064, 0.40384615384615385, 'X[1] <= 3.064\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.042505343783398646, 0.36538461538461536, 'X[1] <= 3.01\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04214909155682223, 0.3269230769230769, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.042861596009975064, 0.3269230769230769, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.043217848236551476, 0.36538461538461536, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.043574100463127895, 0.40384615384615385, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.044642857142857144, 0.4423076923076923, 'X[1] <= 3.524\nentropy = 0.431\nsamples = 34\nvalue = [31, 3]'),
#  Text(0.044286604916280725, 0.40384615384615385, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.044999109369433556, 0.40384615384615385, 'X[1] <= 3.549\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.044642857142857144, 0.36538461538461536, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.045355361596009974, 0.36538461538461536, 'X[1] <= 3.803\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.044999109369433556, 0.3269230769230769, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.04571161382258639, 0.3269230769230769, 'X[1] <= 3.83\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.045355361596009974, 0.28846153846153844, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.046067866049162805, 0.28846153846153844, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.044642857142857144, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.044999109369433556, 0.5192307692307693, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.045355361596009974, 0.5576923076923077, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04571161382258639, 0.5961538461538461, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.045355361596009974, 0.7115384615384616, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04085767723548272, 0.7884615384615384, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(0.052435874599216246, 0.8653846153846154, 'X[2] <= -0.06\nentropy = 0.874\nsamples = 14174\nvalue = [4174, 10000]'),
#  Text(0.051723370146063416, 0.8269230769230769, 'X[0] <= -0.313\nentropy = 0.878\nsamples = 13963\nvalue = [4153, 9810]'),
#  Text(0.051367117919487, 0.7884615384615384, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.05207962237263983, 0.7884615384615384, 'X[0] <= -0.312\nentropy = 0.877\nsamples = 13948\nvalue = [4138, 9810]'),
#  Text(0.04989757748485928, 0.75, 'X[0] <= -0.312\nentropy = 0.998\nsamples = 119\nvalue = [56, 63]'),
#  Text(0.04838350552190951, 0.7115384615384616, 'X[0] <= -0.312\nentropy = 0.8\nsamples = 70\nvalue = [17, 53]'),
#  Text(0.04749287495546847, 0.6730769230769231, 'X[0] <= -0.313\nentropy = 0.485\nsamples = 38\nvalue = [4, 34]'),
#  Text(0.04678037050231564, 0.6346153846153846, 'X[0] <= -0.313\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.04642411827573922, 0.5961538461538461, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.047136622728892054, 0.5961538461538461, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0482053794086213, 0.6346153846153846, 'X[0] <= -0.313\nentropy = 0.196\nsamples = 33\nvalue = [1, 32]'),
#  Text(0.047849127182044884, 0.5961538461538461, 'entropy = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.04856163163519772, 0.5961538461538461, 'X[0] <= -0.313\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.0482053794086213, 0.5576923076923077, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.048917883861774134, 0.5576923076923077, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.04927413608835055, 0.6730769230769231, 'X[0] <= -0.312\nentropy = 0.974\nsamples = 32\nvalue = [13, 19]'),
#  Text(0.048917883861774134, 0.6346153846153846, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.04963038831492697, 0.6346153846153846, 'X[0] <= -0.312\nentropy = 0.795\nsamples = 25\nvalue = [6, 19]'),
#  Text(0.04927413608835055, 0.5961538461538461, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.04998664054150338, 0.5961538461538461, 'X[0] <= -0.312\nentropy = 0.954\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.04963038831492697, 0.5576923076923077, 'X[0] <= -0.312\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.04927413608835055, 0.5192307692307693, 'X[0] <= -0.312\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.048917883861774134, 0.4807692307692308, 'entropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.04963038831492697, 0.4807692307692308, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04998664054150338, 0.5192307692307693, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0503428927680798, 0.5576923076923077, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.05141164944780905, 0.7115384615384616, 'X[0] <= -0.312\nentropy = 0.73\nsamples = 49\nvalue = [39, 10]'),
#  Text(0.05105539722123263, 0.6730769230769231, 'entropy = 0.0\nsamples = 26\nvalue = [26, 0]'),
# ...
#  Text(0.10948076237976487, 0.40384615384615385, 'X[0] <= -0.276\nentropy = 0.469\nsamples = 40\nvalue = [4, 36]'),
#  Text(0.10912451015318846, 0.36538461538461536, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1098370146063413, 0.36538461538461536, 'X[0] <= -0.276\nentropy = 0.391\nsamples = 39\nvalue = [3, 36]'),
#  Text(0.10948076237976487, 0.3269230769230769, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.1101932668329177, 0.3269230769230769, 'X[0] <= -0.276\nentropy = 0.544\nsamples = 24\nvalue = [3, 21]'),
#  Text(0.1098370146063413, 0.28846153846153844, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11054951905949412, 0.28846153846153844, 'X[0] <= -0.276\nentropy = 0.439\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.1101932668329177, 0.25, 'X[0] <= -0.276\nentropy = 0.297\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.1098370146063413, 0.21153846153846154, 'X[0] <= -0.276\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.10948076237976487, 0.17307692307692307, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.1101932668329177, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11054951905949412, 0.21153846153846154, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.11090577128607054, 0.25, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10912451015318846, 0.5192307692307693, 'entropy = 0.0\nsamples = 154\nvalue = [0, 154]'),
#  Text(0.11700659066619166, 0.5576923076923077, 'X[0] <= -0.275\nentropy = 0.396\nsamples = 307\nvalue = [24, 283]'),
#  Text(0.11629408621303883, 0.5192307692307693, 'X[0] <= -0.275\nentropy = 0.438\nsamples = 232\nvalue = [21, 211]'),
#  Text(0.11593783398646242, 0.4807692307692308, 'X[0] <= -0.275\nentropy = 0.411\nsamples = 230\nvalue = [19, 211]'),
#  Text(0.11491360883505522, 0.4423076923076923, 'X[0] <= -0.276\nentropy = 0.326\nsamples = 168\nvalue = [10, 158]'),
#  Text(0.11393391521197008, 0.40384615384615385, 'X[0] <= -0.276\nentropy = 0.417\nsamples = 107\nvalue = [9, 98]'),
#  Text(0.11304328464552904, 0.36538461538461536, 'X[0] <= -0.276\nentropy = 0.358\nsamples = 103\nvalue = [7, 96]'),
#  Text(0.1123307801923762, 0.3269230769230769, 'X[0] <= -0.276\nentropy = 0.491\nsamples = 56\nvalue = [6, 50]'),
#  Text(0.11197452796579979, 0.28846153846153844, 'X[0] <= -0.276\nentropy = 0.381\nsamples = 54\nvalue = [4, 50]'),
#  Text(0.11161827573922337, 0.25, 'X[0] <= -0.276\nentropy = 0.555\nsamples = 31\nvalue = [4, 27]'),
#  Text(0.11126202351264695, 0.21153846153846154, 'X[0] <= -0.276\nentropy = 0.469\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.11090577128607054, 0.17307692307692307, 'X[0] <= -0.276\nentropy = 0.696\nsamples = 16\nvalue = [3, 13]'),
#  Text(0.11054951905949412, 0.1346153846153846, 'entropy = 0.371\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.11126202351264695, 0.1346153846153846, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11161827573922337, 0.17307692307692307, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.11197452796579979, 0.21153846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1123307801923762, 0.25, 'entropy = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(0.11268703241895262, 0.28846153846153844, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11375578909868186, 0.3269230769230769, 'X[0] <= -0.276\nentropy = 0.149\nsamples = 47\nvalue = [1, 46]'),
#  Text(0.11339953687210545, 0.28846153846153844, 'entropy = 0.0\nsamples = 39\nvalue = [0, 39]'),
#  Text(0.11411204132525828, 0.28846153846153844, 'X[0] <= -0.276\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.11375578909868186, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1144682935518347, 0.25, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.11482454577841111, 0.36538461538461536, 'X[0] <= -0.276\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.1144682935518347, 0.3269230769230769, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11518079800498753, 0.3269230769230769, 'X[0] <= -0.276\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11482454577841111, 0.28846153846153844, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11553705023156395, 0.28846153846153844, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11589330245814036, 0.40384615384615385, 'X[0] <= -0.275\nentropy = 0.121\nsamples = 61\nvalue = [1, 60]'),
#  Text(0.11553705023156395, 0.36538461538461536, 'entropy = 0.0\nsamples = 41\nvalue = [0, 41]'),
#  Text(0.11624955468471677, 0.36538461538461536, 'X[0] <= -0.275\nentropy = 0.286\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.11589330245814036, 0.3269230769230769, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1166058069112932, 0.3269230769230769, 'entropy = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.11696205913786961, 0.4423076923076923, 'X[0] <= -0.275\nentropy = 0.598\nsamples = 62\nvalue = [9, 53]'),
#  Text(0.1166058069112932, 0.40384615384615385, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.11731831136444602, 0.40384615384615385, 'X[0] <= -0.275\nentropy = 0.225\nsamples = 55\nvalue = [2, 53]'),
#  Text(0.11696205913786961, 0.36538461538461536, 'entropy = 0.0\nsamples = 34\nvalue = [0, 34]'),
#  Text(0.11767456359102245, 0.36538461538461536, 'X[0] <= -0.275\nentropy = 0.454\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.11731831136444602, 0.3269230769230769, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11803081581759886, 0.3269230769230769, 'entropy = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.11665033843961525, 0.4807692307692308, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1177190951193445, 0.5192307692307693, 'X[0] <= -0.275\nentropy = 0.242\nsamples = 75\nvalue = [3, 72]'),
#  Text(0.11736284289276808, 0.4807692307692308, 'entropy = 0.0\nsamples = 39\nvalue = [0, 39]'),
#  Text(0.11807534734592091, 0.4807692307692308, 'X[0] <= -0.275\nentropy = 0.414\nsamples = 36\nvalue = [3, 33]'),
#  Text(0.1177190951193445, 0.4423076923076923, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.11843159957249733, 0.4423076923076923, 'X[0] <= -0.275\nentropy = 0.206\nsamples = 31\nvalue = [1, 30]'),
#  Text(0.11807534734592091, 0.40384615384615385, 'entropy = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.11878785179907374, 0.40384615384615385, 'X[0] <= -0.275\nentropy = 0.371\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.11843159957249733, 0.36538461538461536, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11914410402565016, 0.36538461538461536, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.12368631991449947, 0.6346153846153846, 'X[0] <= -0.275\nentropy = 1.0\nsamples = 155\nvalue = [78, 77]'),
#  Text(0.12333006768792305, 0.5961538461538461, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.12404257214107588, 0.5961538461538461, 'X[0] <= -0.275\nentropy = 0.997\nsamples = 144\nvalue = [67, 77]'),
#  Text(0.12368631991449947, 0.5576923076923077, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.1243988243676523, 0.5576923076923077, 'X[0] <= -0.274\nentropy = 1.0\nsamples = 132\nvalue = [67, 65]'),
#  Text(0.12404257214107588, 0.5192307692307693, 'X[0] <= -0.274\nentropy = 0.998\nsamples = 127\nvalue = [67, 60]'),
#  Text(0.12368631991449947, 0.4807692307692308, 'X[0] <= -0.274\nentropy = 1.0\nsamples = 122\nvalue = [62, 60]'),
#  Text(0.12333006768792305, 0.4423076923076923, 'X[0] <= -0.274\nentropy = 0.999\nsamples = 119\nvalue = [62, 57]'),
#  Text(0.12110349127182045, 0.40384615384615385, 'X[0] <= -0.274\nentropy = 0.998\nsamples = 97\nvalue = [46, 51]'),
#  Text(0.11985660847880299, 0.36538461538461536, 'X[0] <= -0.275\nentropy = 0.991\nsamples = 79\nvalue = [44, 35]'),
#  Text(0.11878785179907374, 0.3269230769230769, 'X[0] <= -0.275\nentropy = 0.965\nsamples = 41\nvalue = [16, 25]'),
#  Text(0.11843159957249733, 0.28846153846153844, 'X[0] <= -0.275\nentropy = 0.918\nsamples = 24\nvalue = [16, 8]'),
#  Text(0.1177190951193445, 0.25, 'X[0] <= -0.275\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.11736284289276808, 0.21153846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11807534734592091, 0.21153846153846154, 'X[0] <= -0.275\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.1177190951193445, 0.17307692307692307, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11843159957249733, 0.17307692307692307, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.11914410402565016, 0.25, 'X[0] <= -0.275\nentropy = 0.544\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.11878785179907374, 0.21153846153846154, 'entropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.11950035625222657, 0.21153846153846154, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.11914410402565016, 0.28846153846153844, 'entropy = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.12092536515853224, 0.3269230769230769, 'X[0] <= -0.275\nentropy = 0.831\nsamples = 38\nvalue = [28, 10]'),
#  Text(0.12056911293195582, 0.28846153846153844, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.12128161738510866, 0.28846153846153844, 'X[0] <= -0.275\nentropy = 0.951\nsamples = 27\nvalue = [17, 10]'),
#  Text(0.12056911293195582, 0.25, 'X[0] <= -0.275\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.12021286070537941, 0.21153846153846154, 'X[0] <= -0.275\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11985660847880299, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12056911293195582, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12092536515853224, 0.21153846153846154, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.12199412183826149, 0.25, 'X[0] <= -0.275\nentropy = 0.792\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.12163786961168507, 0.21153846153846154, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.12235037406483791, 0.21153846153846154, 'X[0] <= -0.275\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.12199412183826149, 0.17307692307692307, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12270662629141432, 0.17307692307692307, 'entropy = 0.918\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.12235037406483791, 0.36538461538461536, 'X[0] <= -0.274\nentropy = 0.503\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.12199412183826149, 0.3269230769230769, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.12270662629141432, 0.3269230769230769, 'X[0] <= -0.274\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.12235037406483791, 0.28846153846153844, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12306287851799073, 0.28846153846153844, 'X[0] <= -0.274\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.12270662629141432, 0.25, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.12341913074456716, 0.25, 'X[0] <= -0.274\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.12306287851799073, 0.21153846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12377538297114357, 0.21153846153846154, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.12555664410402564, 0.40384615384615385, 'X[0] <= -0.274\nentropy = 0.845\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.12520039187744925, 0.36538461538461536, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.12591289633060207, 0.36538461538461536, 'X[0] <= -0.274\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.12555664410402564, 0.3269230769230769, 'X[0] <= -0.274\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.12520039187744925, 0.28846153846153844, 'X[0] <= -0.274\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.12484413965087282, 0.25, 'X[0] <= -0.274\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1244878874242964, 0.21153846153846154, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12520039187744925, 0.21153846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12555664410402564, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12591289633060207, 0.28846153846153844, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1262691485571785, 0.3269230769230769, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12404257214107588, 0.4423076923076923, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1243988243676523, 0.4807692307692308, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.12475507659422871, 0.5192307692307693, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.13076683291770574, 0.7115384615384616, 'X[0] <= -0.28\nentropy = 0.73\nsamples = 255\nvalue = [203, 52]'),
#  Text(0.12822853580334878, 0.6730769230769231, 'X[1] <= 0.947\nentropy = 0.471\nsamples = 209\nvalue = [188, 21]'),
#  Text(0.12707071606697543, 0.6346153846153846, 'X[1] <= 0.479\nentropy = 0.159\nsamples = 43\nvalue = [42, 1]'),
#  Text(0.126714463840399, 0.5961538461538461, 'X[1] <= 0.459\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.12635821161382257, 0.5576923076923077, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.12707071606697543, 0.5576923076923077, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12742696829355182, 0.5961538461538461, 'entropy = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(0.12938635553972214, 0.6346153846153846, 'X[0] <= -0.286\nentropy = 0.531\nsamples = 166\nvalue = [146, 20]'),
#  Text(0.12849572497328107, 0.5961538461538461, 'X[0] <= -0.288\nentropy = 0.779\nsamples = 39\nvalue = [30, 9]'),
#  Text(0.12778322052012825, 0.5576923076923077, 'X[1] <= 0.96\nentropy = 0.533\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.12742696829355182, 0.5192307692307693, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12813947274670467, 0.5192307692307693, 'X[1] <= 3.669\nentropy = 0.449\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.12778322052012825, 0.4807692307692308, 'X[1] <= 1.562\nentropy = 0.345\nsamples = 31\nvalue = [29, 2]'),
#  Text(0.12742696829355182, 0.4423076923076923, 'X[1] <= 1.333\nentropy = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.12707071606697543, 0.40384615384615385, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.12778322052012825, 0.40384615384615385, 'X[0] <= -0.293\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12742696829355182, 0.36538461538461536, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12813947274670467, 0.36538461538461536, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12813947274670467, 0.4423076923076923, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.12849572497328107, 0.4807692307692308, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12920822942643392, 0.5576923076923077, 'X[1] <= 1.12\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.1288519771998575, 0.5192307692307693, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12956448165301032, 0.5192307692307693, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.13027698610616317, 0.5961538461538461, 'X[0] <= -0.285\nentropy = 0.425\nsamples = 127\nvalue = [116, 11]'),
#  Text(0.12992073387958675, 0.5576923076923077, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.13063323833273957, 0.5576923076923077, 'X[1] <= 3.609\nentropy = 0.463\nsamples = 112\nvalue = [101, 11]'),
#  Text(0.13027698610616317, 0.5192307692307693, 'X[1] <= 3.458\nentropy = 0.497\nsamples = 101\nvalue = [90, 11]'),
#  Text(0.12992073387958675, 0.4807692307692308, 'X[1] <= 2.76\nentropy = 0.439\nsamples = 99\nvalue = [90, 9]'),
#  Text(0.12956448165301032, 0.4423076923076923, 'X[1] <= 2.689\nentropy = 0.48\nsamples = 87\nvalue = [78, 9]'),
#  Text(0.12920822942643392, 0.40384615384615385, 'X[1] <= 2.287\nentropy = 0.446\nsamples = 86\nvalue = [78, 8]'),
#  Text(0.1288519771998575, 0.36538461538461536, 'X[1] <= 2.268\nentropy = 0.513\nsamples = 70\nvalue = [62, 8]'),
#  Text(0.12849572497328107, 0.3269230769230769, 'X[1] <= 1.441\nentropy = 0.474\nsamples = 69\nvalue = [62, 7]'),
#  Text(0.12751603135019593, 0.28846153846153844, 'X[1] <= 1.366\nentropy = 0.634\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.1266254007837549, 0.25, 'X[0] <= -0.282\nentropy = 0.439\nsamples = 22\nvalue = [20, 2]'),
#  ...]

# %% [markdown]
# ## Análise dados de TESTE

# %%
previsoes_arvore = arvore.predict(x_teste)
previsoes_arvore
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
y_teste
# meu array real (que o de cima deveria ter previsto)
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print("Acurácia no conjunto de TESTE de: %.2f%%" % (accuracy_score(y_teste, previsoes_arvore) * 100.0))
# Out:
# Acurácia no conjunto de TESTE de: 86.76%

# %% [markdown]
# NA MATRIX DE CONFUSÃO DE TESTE:
#
# **Resultado**
#
# **Acertou:** 17761 previu ser gastos do INSS; 16803 previu ser gasto da PF.
#
# **Errou:** 2439 previu ser gasto do INSS; 2837 previu ser gasto da PF.

# %%
confusion_matrix(y_teste, previsoes_arvore)
# Out:
# array([[17761,  2439],
#        [ 2837, 16803]])

# %%
print(classification_report(y_teste, previsoes_arvore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86     20200
#            1       0.88      0.83      0.85     19640
#
#     accuracy                           0.86     39840
#    macro avg       0.86      0.86      0.86     39840
# weighted avg       0.86      0.86      0.86     39840

# %% [markdown]
# ## Análise dados de TREINO

# %%
previsoes_treino = arvore.predict(x_treino)
previsoes_treino
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
print("Acurácia no conjunto de TREINO de: %.2f%%" % (accuracy_score(y_treino, previsoes_treino) * 100.0 ))
# Out:
# Acurácia no conjunto de TREINO de: 89.78%

# %% [markdown]
# NA MATRIX DE CONFUSÃO DE TREINO:
#
# **Resultado**
#
# **Acertou:** 42349 previu ser gasto do INSS, 41107 previu ser gasto da PF.
#
# **Errou:** 4441 previu ser gsto do INSS, 5062 previu ser gasto da PF.

# %%
confusion_matrix(y_treino, previsoes_treino)
# Out:
# array([[42349,  4441],
#        [ 5062, 41107]])

# %% [markdown]
# ### Árvore de decisão = 89.78% (treino) e 86.76% (teste) - 34.564 acertos

# %% [markdown]
# # **Random Forests**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random = RandomForestClassifier(n_estimators=150, criterion='entropy', random_state = 0, max_depth=25)
random.fit(x_treino, y_treino)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=25, n_estimators=150,
#                        random_state=0)

# %%
previsoes_random = random.predict(x_teste)
previsoes_random
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
y_teste
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print("Acurácia de teste: %.2f%%" % (accuracy_score(y_teste, previsoes_random) * 100.0))
# Out:
# Acurácia de teste: 86.88%

# %%
confusion_matrix(y_teste, previsoes_random)
# Out:
# array([[17936,  2264],
#        [ 2962, 16678]])

# %%
print(classification_report(y_teste, previsoes_random))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87     20200
#            1       0.88      0.85      0.86     19640
#
#     accuracy                           0.87     39840
#    macro avg       0.87      0.87      0.87     39840
# weighted avg       0.87      0.87      0.87     39840

# %% [markdown]
# Análise dados de treino

# %%
previsoes_treino = random.predict(x_treino)
previsoes_treino
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
print("Acurácia de treino: %.2f%%" % (accuracy_score(y_treino, previsoes_treino) * 100.0 ))
# Out:
# Acurácia de treino: 89.83%

# %%
confusion_matrix(y_treino, previsoes_treino)
# Out:
# array([[42526,  4264],
#        [ 5186, 40983]])

# %% [markdown]
# ### Random Forest = 89.83% (treino) e 86.88% (teste) - 34.614 acertos

# %% [markdown]
# # **Regressão Logística**

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistica = LogisticRegression(random_state=1, max_iter=500, penalty="l2",
                               tol=0.0001, C=2,solver="lbfgs")
logistica.fit(x_treino, y_treino)
# C é quão fino fica sua curva S, default = 1
# penalty função que muda  ajuste do erro (distancia) l1, l2
# Out:
# LogisticRegression(C=2, max_iter=500, random_state=1)

# %%
logistica.intercept_
# Out:
# array([0.46214356])

# %%
logistica.coef_
# Out:
# array([[-2.43931767, -0.12733166,  0.09704853,  4.73215461]])

# %%
previsoes_logistica = logistica.predict(x_teste)
previsoes_logistica
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print("Acurácia de TESTE: %.2f%%" % (accuracy_score(y_teste, previsoes_logistica) * 100.0))
# Out:
# Acurácia de TESTE: 73.57%

# %%
confusion_matrix(y_teste, previsoes_logistica)
# Out:
# array([[20001,   199],
#        [10329,  9311]])

# %%
print(classification_report(y_teste, previsoes_logistica))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.99      0.79     20200
#            1       0.98      0.47      0.64     19640
#
#     accuracy                           0.74     39840
#    macro avg       0.82      0.73      0.72     39840
# weighted avg       0.82      0.74      0.72     39840

# %% [markdown]
# Análise dados de treino

# %%
previsoes_treino = logistica.predict(x_treino)
previsoes_treino
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
print("Acurácia de TREINO: %.2f%%" % (accuracy_score(y_treino, previsoes_treino) *100.0))
# Out:
# Acurácia de TREINO: 73.69%

# %%
confusion_matrix(y_treino, previsoes_treino)
# Out:
# array([[46266,   524],
#        [23930, 22239]])

# %% [markdown]
# ### Regressão Logística = 73.69% (treino) e 73.57% (teste) - 29.312 acertos

# %% [markdown]
# # CONCLUSÃO
#
# o Algorítimo que apresentou o melhor resultado foi o Random Forests, 34.614 acertos,
# comprovando a expectativa de ser o mais robusto, complexo e propiciando resultados melhores.​
